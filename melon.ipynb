# %%
import requests

head = {'User-Agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"}

# %%
url = "https://www.melon.com/chart/index.htm"

# %%
res = requests.get(url,headers=head)

# %%
res.status_code
# Out:
# 200

# %%
res.raise_for_status
# Out:
# <bound method Response.raise_for_status of <Response [200]>>

# %%
from bs4 import BeautifulSoup

bs = BeautifulSoup(res.text, "lxml")

# %%
bs.find("span", class_="year")
# Out:
# <span class="year">2023.08.16</span>

# %%
bs.find("table")
# Out:
# <table border="1" style="width:100%">
# <caption>이 표는 곡 리스트로 체크박스, 순위, 곡정보, 좋아요, 뮤비, 다운, 폰전송 내용을 포함하고 있으며 표 상 하단에 제공하는 전체선택, 듣기, 다운로드, 담기, 선물하기 기능을 이용하실 수 있습니다.</caption>
# <colgroup>
# <col style="width: 15px"/><!-- checkbox -->
# <col style="width: 62px"/><!-- 순서 & 순위 -->
# <col style="width: 50px"/><!-- 순위등락 -->
# <col style="width: 60px"/><!-- 앨범이미지 -->
# <col style="width: 24px"/><!-- 곡 상세가기 -->
# <col/><!-- 곡정보 -->
# <col style="width: 190px"/><!-- 앨범 -->
# <col style="width: 111px"/><!-- 좋아요 -->
# <col style="width: 58px"/><!-- 듣기 -->
# <col style="width: 52px"/><!-- 담기 -->
# <col style="width: 52px"/><!-- 다운 -->
# <col style="width: 52px"/><!-- 뮤비 -->
# </colgroup>
# <thead>
# <tr>
# <th scope="col">
# <div class="wrap t_right"><input class="input_check d_checkall" title="곡 목록 전체 선택" type="checkbox"/></div>
# </th>
# <th scope="col">
# <div class="wrap t_center"><span class="rank">순위</span></div>
# </th>
# <th scope="col">
# <div class="wrap none">순위등락</div>
# </th>
# ...

# %%
lylic = bs.find_all("a", attrs={"class":'btn button_icons type03 song_info'})

# %%
name = bs.find_all("div", class_='ellipsis rank02')
names = [x.find("a").text for x in name]
names
# Out:
# ['정국',
#  'NewJeans',
#  'NewJeans',
#  '(여자)아이들',
#  '박재정',
#  'IVE (아이브)',
#  'aespa',
#  'Lauv',
#  'NewJeans',
#  'LE SSERAFIM (르세라핌)',
#  'NewJeans',
#  '임영웅',
#  '임영웅',
#  '우디 (Woody)',
#  'IVE (아이브)',
#  'LE SSERAFIM (르세라핌)',
#  '정국',
#  '임영웅',
#  'NewJeans',
#  '임영웅',
#  'NewJeans',
#  '임영웅',
#  'Paul Blanco',
#  '임영웅',
#  'NewJeans',
#  '임영웅',
#  'NewJeans',
#  '임영웅',
#  '임영웅',
#  '방탄소년단',
#  '세븐틴 (SEVENTEEN)',
#  '임영웅',
#  'IVE (아이브)',
#  '임영웅',
#  '윤하 (YOUNHA)',
#  '임영웅',
#  '지수 (JISOO)',
#  'IVE (아이브)',
#  '임영웅',
#  '방탄소년단',
#  '임영웅',
#  '전소미',
#  'Charlie Puth',
#  'NCT DREAM',
#  '방탄소년단',
#  'NCT DREAM',
#  'Charlie Puth',
#  'V',
#  '이무진',
#  '임영웅',
#  '부석순 (SEVENTEEN)',
#  '방탄소년단',
#  '정국',
#  'STAYC(스테이씨)',
#  '지민',
#  'Agust D',
#  'DK(디셈버)',
#  '임한별',
#  'NewJeans',
#  '탑현',
#  '성시경',
#  '멜로망스',
#  'LE SSERAFIM (르세라핌)',
#  'FIFTY FIFTY',
#  '(여자)아이들',
#  '허각',
#  '방탄소년단',
#  '지아',
#  'NCT DREAM',
#  '오마이걸 (OH MY GIRL)',
#  'H1-KEY (하이키)',
#  'j-hope',
# ...

# %%
lylic[:5]
# Out:
# [<a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36617841');" title="Seven (feat. Latto) - Clean Ver. 곡정보"><span class="none">곡정보</span></a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36599950');" title="Super Shy 곡정보"><span class="none">곡정보</span></a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36635522');" title="ETA 곡정보"><span class="none">곡정보</span></a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36430773');" title="퀸카 (Queencard) 곡정보"><span class="none">곡정보</span></a>,
#  <a class="btn button_icons type03 song_info" href="javascript:melon.link.goSongDetail('36382580');" title="헤어지자 말해요 곡정보"><span class="none">곡정보</span></a>]

# %%
lylic[0].find("a").text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\2342782287.py in <module>
# ----> 1 lylic[1].find("a").text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
numbers = [re.search(r'\d{7}', str(item)).group() for item in lylic]
numbers
# Out:
# ['3661784',
#  '3659995',
#  '3663552',
#  '3643077',
#  '3638258',
#  '3635699',
#  '3641611',
#  '3649042',
#  '3659994',
#  '3641134',
#  '3545442',
#  '3650291',
#  '3406132',
#  '3661637',
#  '3631812',
#  '3641134',
#  '3658140',
#  '3490874',
#  '3594592',
#  '3500852',
#  '3663290',
#  '3500852',
#  '3529969',
#  '3250805',
#  '3545442',
#  '3583458',
#  '3598516',
#  '3583458',
#  '3500852',
#  '3287297',
#  '3639123',
#  '3500853',
#  '3554649',
#  '3500852',
#  '3481947',
#  '3500852',
#  '3633112',
#  '3484737',
#  '3500853',
#  '3651632',
#  '3500853',
#  '3668107',
#  '3564075',
#  '3654689',
#  '3024493',
#  '3593153',
#  '8037843',
#  '3669182',
#  '3642868',
#  '3500853',
#  '3611099',
#  '3350713',
#  '3584986',
#  '3610554',
#  '3631311',
#  '3635199',
#  '3618070',
#  '3633440',
#  '3663552',
#  '3651834',
#  '4446485',
#  '3465784',
#  '3572910',
#  '3620625',
#  '3643077',
#  '3640485',
#  '3366626',
#  '3644024',
#  '3654689',
#  '3663782',
#  '3600129',
# ...

# %%
titles = [item['title'].replace('곡정보','').strip() for item in lylic]
titles
# Out:
# ['Seven (feat. Latto) - Clean Ver.',
#  'Super Shy',
#  'ETA',
#  '퀸카 (Queencard)',
#  '헤어지자 말해요',
#  'I AM',
#  'Spicy',
#  'Steal The Show (From “엘리멘탈”)',
#  'New Jeans',
#  '이브, 프시케 그리고 푸른 수염의 아내',
#  'Hype boy',
#  '모래 알갱이',
#  '사랑은 늘 도망가',
#  '사막에서 꽃을 피우듯',
#  'Kitsch',
#  'UNFORGIVEN (feat. Nile Rodgers)',
#  'Still With You',
#  '우리들의 블루스',
#  'Ditto',
#  '다시 만날 수 있을까',
#  'Cool With You',
#  '무지개',
#  'Summer (Feat. BE’O (비오))',
#  '이제 나만 믿어요',
#  'Attention',
#  'London Boy',
#  'OMG',
#  'Polaroid',
#  '아버지',
#  'Dynamite',
#  '손오공',
#  '인생찬가',
#  'After LIKE',
#  'A bientot',
#  '사건의 지평선',
#  '손이 참 곱던 그대',
#  '꽃',
#  'LOVE DIVE',
#  '사랑해 진짜',
#  'Take Two',
#  '연애편지',
#  'Fast Forward',
#  "I Don't Think That I Like Her",
#  'ISTJ',
#  '봄날',
#  'Candy',
#  'Dangerously',
#  'Love Me Again',
#  '잠깐 시간 될까',
#  '보금자리',
#  '파이팅 해야지 (Feat. 이영지)',
#  'Butter',
#  'Dreamers [Music from the FIFA World Cup Qatar 2022 Official Soundtrack] (Feat. FIFA Sound)',
#  'Teddy Bear',
# ...

# %%
import re
re.search(r'[1-9+]',lylic[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\3469231385.py in <module>
#       1 import re
# ----> 2 re.search(r'[1-9+]',lylic[0])
#
# c:\Users\user\Anaconda3\lib\re.py in search(pattern, string, flags)
#     199     """Scan through string looking for a match to the pattern, returning
#     200     a Match object, or None if no match was found."""
# --> 201     return _compile(pattern, flags).search(string)
#     202
#     203 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
for i in lylic:
    print(i.find("a", attrs={"class":"btn button_icons type03 song_info"}).get_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\1360093696.py in <module>
#       1 for i in lylic:
# ----> 2     print(i.find("a", attrs={"class":"btn button_icons type03 song_info"}).get_text)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
import pandas as pd

melon = pd.read_html(res.text)[0][['순위','곡정보','앨범']]

# %%
from datetime import date, datetime, timedelta

# %%
date.today()
# Out:
# datetime.date(2023, 8, 16)

# %%
timedelta(23)
# Out:
# datetime.timedelta(days=23)

# %%
for x in range(100, 10001, 100):
    print(date.today() + timedelta(days=x))
# Out:
# 2023-11-24
# 2024-03-03
# 2024-06-11
# 2024-09-19
# 2024-12-28
# 2025-04-07
# 2025-07-16
# 2025-10-24
# 2026-02-01
# 2026-05-12
# 2026-08-20
# 2026-11-28
# 2027-03-08
# 2027-06-16
# 2027-09-24
# 2028-01-02
# 2028-04-11
# 2028-07-20
# 2028-10-28
# 2029-02-05
# 2029-05-16
# 2029-08-24
# 2029-12-02
# 2030-03-12
# 2030-06-20
# 2030-09-28
# 2031-01-06
# 2031-04-16
# 2031-07-25
# 2031-11-02
# 2032-02-10
# 2032-05-20
# 2032-08-28
# 2032-12-06
# 2033-03-16
# 2033-06-24
# 2033-10-02
# 2034-01-10
# 2034-04-20
# 2034-07-29
# 2034-11-06
# 2035-02-14
# 2035-05-25
# 2035-09-02
# 2035-12-11
# 2036-03-20
# 2036-06-28
# 2036-10-06
# 2037-01-14
# 2037-04-24
# 2037-08-02
# 2037-11-10
# 2038-02-18
# 2038-05-29
# 2038-09-06
# 2038-12-15
# 2039-03-25
# 2039-07-03
# 2039-10-11
# 2040-01-19
# 2040-04-28
# 2040-08-06
# 2040-11-14
# 2041-02-22
# 2041-06-02
# 2041-09-10
# 2041-12-19
# 2042-03-29
# 2042-07-07
# 2042-10-15
# 2043-01-23
# 2043-05-03
# 2043-08-11
# 2043-11-19
# 2044-02-27
# 2044-06-06
# ...

# %%
melon.head()
# Out:
#    순위                                   곡정보                                앨범  \
# 0  1위  Seven (feat. Latto) - Clean Ver.  정국  Seven (feat. Latto) - Clean Ver.
# 1  2위                   Super Shy  NewJeans          NewJeans 2nd EP 'Get Up'
# 2  3위                         ETA  NewJeans          NewJeans 2nd EP 'Get Up'
# 3  4위               퀸카 (Queencard)  (여자)아이들                            I feel
# 4  5위                         헤어지자 말해요  박재정                          1집 Alone
#
#           기록일
# 0  2023-08-16
# 1  2023-08-16
# 2  2023-08-16
# 3  2023-08-16
# 4  2023-08-16

# %%
melon['기록일'] = str(date.today())

# %%
import sqlalchemy
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5756\2540049086.py in <module>
#       1 import sqlalchemy
#       2 import pymysql
# ----> 3 import mysqlclient
#
# ModuleNotFoundError: No module named 'mysqlclient'

# %%
# db 설정

user = 'root'
password = '1234'
host = '127.0.0.1'
port = '80'
database = 'encore'

engine = sqlalchemy.create_engine(f'mysql://{user}:{password}@{host}{port}/{database}')
melon.to_sql(con=engine, if_exists='replace', name = 'melon')
# Out:
# 100

# %%
#names, numbers, titles
